# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme()

#from pandas_profiling import ProfileReport

from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

from sklearn import linear_model

random_param_test = 3
random_param_cv = 13

from sklearn.metrics import mean_absolute_error

# %%
df_full = pd.read_csv('student-por.csv', sep = ';')

# %%
df_full.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df_full.shape
# Out:
# (649, 33)

# %%
## To do later:

## 1
#Dropping outliers: 
#Remove the 15 students who did not take the G3 exam. This includes 15 students, or 2.3% of the total population.

df_drop_outliers = df_full.loc[ df_full['G3'] != 0 ]

display(df_drop_outliers.shape)





## 2
# Keep selected subset of columns only
# Improve interpretabliltiy by running the model with only the important features

my_cols = ['school','sex','failures','higher','Medu','Fedu','G3']
df_subset = df_full[my_cols].copy()

df_subset.head(10)
# Out:
# (634, 33)
#   school sex  failures higher  Medu  Fedu  G3
# 0     GP   F         0    yes     4     4  11
# 1     GP   F         0    yes     1     1  11
# 2     GP   F         0    yes     1     1  12
# 3     GP   F         0    yes     4     2  14
# 4     GP   F         0    yes     3     3  13
# 5     GP   M         0    yes     4     3  13
# 6     GP   M         0    yes     2     2  13
# 7     GP   F         0    yes     4     4  13
# 8     GP   M         0    yes     3     2  17
# 9     GP   M         0    yes     3     4  13

# %%
#absences is a high cardinality categorical feature, as can be seen by the following box and whisker plot.

sns.catplot(data=df_full, x="absences", y="G3", kind="box" )

# %%
# To make this feature usable by the modeling algorithms, we will bin absences.
# We see that mosts students have 0 absences. 

df_full['absences'].value_counts()
# Out:
# 0     244
# 2     110
# 4      93
# 6      49
# 8      42
# 10     21
# 1      12
# 12     12
# 5      12
# 16     10
# 14      8
# 9       7
# 3       7
# 11      5
# 18      3
# 7       3
# 21      2
# 15      2
# 22      2
# 30      1
# 26      1
# 24      1
# 13      1
# 32      1
# Name: absences, dtype: int64

# %%
# Since 244 students have 0 absences, we will choose to have 3 bins of size about 200.
# Define the function for binning:

def get_absences(N):
    
    if N == 0 :
        return 1
        
    elif N>0 and N<5 :
        return 2
    
    else:
        return 3

# %%
# Create a new feature 'absences_bin' that takes the three values:
# absences_bin = 1 if absences = 0
# absences_bin = 2 if absences = 1,2,3, or 4
# absences_bin = 3 if absences > 4

df_full['absences_bin'] = df_full['absences'].apply(get_absences)

# %%
# We see that the size of the bins are approximately 200

df_full['absences_bin'].value_counts()
# Out:
# 1    244
# 2    222
# 3    183
# Name: absences_bin, dtype: int64

# %%
# We can also see that the behavior of the 'absences_bin' is an improvement over 'absences'. 
# The following plot shows the general trend that more absences correspont to smaller G3 exam score.

sns.catplot(data=df_full, x="absences_bin", y="G3", kind="box" )

# %%
df = df_full.drop(['absences'], axis=1)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health  G1  G2  G3 absences_bin
# 0      4        3      4     1     1      3   0  11  11            2
# 1      5        3      3     1     1      3   9  11  11            2
# 2      4        3      2     2     3      3  12  13  12            3
# 3      3        2      2     1     1      5  14  14  14            1
# 4      4        3      2     1     2      5  11  13  13            1
#
# [5 rows x 33 columns]

# %%
# Separate target from predictors

y = df.G3
X = df.drop(['G1','G2','G3'], axis=1)

# %%
y
# Out:
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 649, dtype: int64

# %%
X.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0    yes       no        no       4         3     4    1    1      3
# 1    yes      yes        no       5         3     3    1    1      3
# 2    yes      yes        no       4         3     2    2    3      3
# 3    yes      yes       yes       3         2     2    1    1      5
# 4    yes       no        no       4         3     2    1    2      5
#
#   absences_bin
# 0            2
# 1            2
# 2            3
# 3            1
# 4            1
#
# [5 rows x 30 columns]

# %%
# Divide data into training and test subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=random_param_test)

# %%
X_train.shape
# Out:
# (519, 30)

# %%
y_train
# Out:
# 27     11
# 43     10
# 130    12
# 294    13
# 136    11
#        ..
# 422    13
# 119    14
# 256     8
# 643    10
# 249    12
# Name: G3, Length: 519, dtype: int64

# %%
X_test.shape
# Out:
# (130, 30)

# %%
# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_train.columns if X_train[cname].nunique() < 10 and 
                        X_train[cname].dtype == "object"]

# %%
categorical_cols
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic']

# %%
len(categorical_cols)
# Out:
# 17

# %%
# Select numerical columns
numerical_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['int64', 'float64']]

# %%
numerical_cols
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences_bin']

# %%
len(numerical_cols)
# Out:
# 13

# %%
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='median')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
model_Forest = RandomForestRegressor(random_state=0)

# %%
# Bundle preprocessing and modeling code in a pipeline
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model_Forest)
                             ])

# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)

# Preprocessing of test data, get predictions
preds = my_pipeline.predict(X_test)

# Evaluate the model
score = mean_absolute_error(y_test, preds)

# %%
#one-hot encoding of the categorical features
#model = RandomForestRegressor
#minimal feature engineering

#The MAE is:
display(score)
# Out:
# 1.9049230769230767

# %%
#We can also cross validate using random subsets:

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=random_param_cv)

# %%
scores2 = cross_val_score(my_pipeline, X_train, y_train, cv=cv, scoring = 'neg_mean_absolute_error')

-scores2
# Out:
# array([1.85576923, 2.045     , 1.90807692, 2.31875   , 1.79288462])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (-scores2.mean(), scores2.std()))
# Out:
# 1.98 accuracy with a standard deviation of 0.19

# %%
model_LinReg_1 = linear_model.LinearRegression()

# %%
# Keep selected subset of columns only
# Improve interpretabliltiy by running the model with only the important features

my_cols = ['failures','G3']
df_subset_1 = df[my_cols].copy()

df_subset_1.head(10)
# Out:
#    failures  G3
# 0         0  11
# 1         0  11
# 2         0  12
# 3         0  14
# 4         0  13
# 5         0  13
# 6         0  13
# 7         0  13
# 8         0  17
# 9         0  13

# %%
# Separate target from predictors

y_subset_1 = df_subset_1.G3
X_subset_1 = df_subset_1.drop(['G3'], axis=1)


# Divide data into training and test subsets

X_train_subset_1, X_test_subset_1, y_train_subset_1, y_test_subset_1 = train_test_split(X_subset_1, y_subset_1, train_size=0.8, test_size=0.2,
                                                                random_state=random_param_test)

# %%
X_train_subset_1.head(10)
# Out:
#      failures
# 27          0
# 43          0
# 130         0
# 294         0
# 136         0
# 211         0
# 578         1
# 541         0
# 463         0
# 170         3

# %%
model_LinReg_1.fit(X_train_subset_1, y_train_subset_1)

# Make predictions using the testing set
y_pred_subset_1 = model_LinReg_1.predict(X_test_subset_1)

# The coefficients
print("Coefficients: \n", model_LinReg_1.coef_)

# The mean absolute error
print("Mean absolute error: %.2f" % mean_absolute_error(y_test_subset_1, y_pred_subset_1))
# Out:
# Coefficients:
#  [-2.27457791]
# Mean absolute error: 2.17

# %%
pd.merge(df_subset_1, X_train_subset_1, left_index=True, right_index=True)
# Out:
#      failures_x  G3  failures_y
# 0             0  11           0
# 1             0  11           0
# 2             0  12           0
# 3             0  14           0
# 4             0  13           0
# ..          ...  ..         ...
# 642           0  11           0
# 643           0  10           0
# 644           1  10           1
# 646           0   9           0
# 647           0  10           0
#
# [519 rows x 3 columns]

# %%
df_subset_1
# Out:
#      failures  G3
# 0           0  11
# 1           0  11
# 2           0  12
# 3           0  14
# 4           0  13
# ..        ...  ..
# 644         1  10
# 645         0  16
# 646         0   9
# 647         0  10
# 648         0  11
#
# [649 rows x 2 columns]

# %%
df_line_fit_1 = df_subset_1.merge(X_train_subset_1,how='right', left_index=True, right_index=True)

# %%
X_train_subset_1
# Out:
#      failures
# 27          0
# 43          0
# 130         0
# 294         0
# 136         0
# ..        ...
# 422         0
# 119         0
# 256         1
# 643         0
# 249         0
#
# [519 rows x 1 columns]

# %%
df_subset_1
# Out:
#      failures  G3
# 0           0  11
# 1           0  11
# 2           0  12
# 3           0  14
# 4           0  13
# ..        ...  ..
# 644         1  10
# 645         0  16
# 646         0   9
# 647         0  10
# 648         0  11
#
# [649 rows x 2 columns]

# %%
df_line_fit_1
# Out:
#      failures_x  G3  failures_y
# 27            0  11           0
# 43            0  10           0
# 130           0  12           0
# 294           0  13           0
# 136           0  11           0
# ..          ...  ..         ...
# 422           0  13           0
# 119           0  14           0
# 256           1   8           1
# 643           0  10           0
# 249           0  12           0
#
# [519 rows x 3 columns]

# %%
df_line_fit_1_drop = df_line_fit_1.drop(['failures_y'], axis=1)

df_line_fit_1_drop
# Out:
#      failures_x  G3
# 27            0  11
# 43            0  10
# 130           0  12
# 294           0  13
# 136           0  11
# ..          ...  ..
# 422           0  13
# 119           0  14
# 256           1   8
# 643           0  10
# 249           0  12
#
# [519 rows x 2 columns]

# %%
df_line_fit_1_drop2 = df_line_fit_1_drop.rename(columns={"failures_x": "failures"})

df_line_fit_1_drop2
# Out:
#      failures  G3
# 27          0  11
# 43          0  10
# 130         0  12
# 294         0  13
# 136         0  11
# ..        ...  ..
# 422         0  13
# 119         0  14
# 256         1   8
# 643         0  10
# 249         0  12
#
# [519 rows x 2 columns]

# %%
# Plot outputs
#plt.scatter(X_test_subset_1, y_test_subset_1, color="black")

sns.catplot(data=df_line_fit_1_drop2, x="failures", y="G3", kind="swarm", s = .9)
plt.plot(X_test_subset_1, y_pred_subset_1, color="blue", linewidth=2)

# %%
scores_LinReg_1 = cross_val_score(model_LinReg_1, X_train_subset_1, y_train_subset_1, cv=cv, scoring = 'neg_mean_absolute_error')

-scores_LinReg_1
# Out:
# array([2.10654776, 2.11254686, 2.08278896, 2.4119659 , 2.21840223])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (-scores_LinReg_1.mean(), scores_LinReg_1.std()))
# Out:
# 2.19 accuracy with a standard deviation of 0.12

# %%
model_LinReg = linear_model.LinearRegression()

# %%
# Keep selected subset of columns only
# Improve interpretabliltiy by running the model with only the important features

my_cols = ['failures','Medu','G3']
df_subset = df[my_cols].copy()

df_subset.head(10)
# Out:
#    failures  Medu  G3
# 0         0     4  11
# 1         0     1  11
# 2         0     1  12
# 3         0     4  14
# 4         0     3  13
# 5         0     4  13
# 6         0     2  13
# 7         0     4  13
# 8         0     3  17
# 9         0     3  13

# %%
df_subset['failures'].value_counts()
# Out:
# 0    549
# 1     70
# 2     16
# 3     14
# Name: failures, dtype: int64

# %%
df_subset['Medu'].value_counts()
# Out:
# 2    186
# 4    175
# 1    143
# 3    139
# 0      6
# Name: Medu, dtype: int64

# %%
# Separate target from predictors

y_subset = df_subset.G3
X_subset = df_subset.drop(['G3'], axis=1)


# Divide data into training and test subsets

X_train_subset, X_test_subset, y_train_subset, y_test_subset = train_test_split(X_subset, y_subset, train_size=0.8, test_size=0.2,
                                                                random_state=random_param_test)

# %%
X_train_subset.head(10)
# Out:
#      failures  Medu
# 27          0     4
# 43          0     2
# 130         0     3
# 294         0     2
# 136         0     2
# 211         0     3
# 578         1     3
# 541         0     2
# 463         0     2
# 170         3     1

# %%
X_train.head(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 43      GP   M   15       U     GT3       T     2     2  services  services
# 130     GP   F   15       R     GT3       T     3     4  services   teacher
# 294     GP   F   18       R     GT3       T     2     2     other     other
# 136     GP   M   16       U     GT3       T     2     1   at_home     other
# 211     GP   M   16       R     LE3       T     3     3   teacher     other
# 578     MS   M   17       U     GT3       T     3     3    health     other
# 541     MS   F   17       R     GT3       T     2     2     other     other
# 463     MS   F   15       R     LE3       T     2     2     other     other
# 170     GP   F   18       R     GT3       T     1     1   at_home     other
#
#      ... higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 27   ...    yes      yes        no       2         2     4    2    4      1
# 43   ...    yes      yes        no       5         4     1    1    1      1
# 130  ...    yes      yes       yes       4         2     2    2    2      5
# 294  ...    yes       no        no       3         2     3    1    1      5
# 136  ...    yes       no        no       3         2     1    1    1      2
# 211  ...    yes      yes        no       3         3     4    3    5      3
# 578  ...    yes      yes        no       4         5     4    2    3      3
# 541  ...    yes       no        no       5         1     3    1    1      5
# 463  ...    yes       no        no       4         4     3    2    2      5
# 170  ...    yes       no        no       5         2     5    1    5      4
#
#     absences_bin
# 27             1
# 43             1
# 130            1
# 294            2
# 136            2
# 211            3
# 578            2
# 541            1
# 463            2
# 170            3
#
# [10 rows x 30 columns]

# %%
model_LinReg.fit(X_train_subset, y_train_subset)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
y_pred_subset = model_LinReg.predict(X_test_subset)

# %%
# The coefficients
print("Coefficients: \n", model_LinReg.coef_)
# Out:
# Coefficients:
#  [-2.10902039  0.54863313]

# %%
# The mean absolute error
print("Mean absolute error: %.2f" % mean_absolute_error(y_test_subset, y_pred_subset))
# Out:
# Mean absolute error: 2.16

# %%
# Plot outputs
plt.scatter(X_test_subset['failures'], y_test_subset, color="black")
plt.plot(X_test_subset['failures'], y_pred_subset, color="blue", linewidth=2)

# %%
scores3 = cross_val_score(model_LinReg, X_train_subset, y_train_subset, cv=cv, scoring = 'neg_mean_absolute_error')

-scores3
# Out:
# array([1.99258358, 1.98413143, 2.06750377, 2.40838067, 2.08947683])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (-scores3.mean(), scores3.std()))
# Out:
# 2.11 accuracy with a standard deviation of 0.16

# %%
## As a comparison, what if predict every student just scores the average?
def Average(lst):
    return sum(lst) / len(lst)

avg = Average(y_train)

display(avg)
# Out:
# 11.86897880539499

# %%
ones_length_test = [1]*len(y_test)

# %%
y_pred_avg = [x * avg for x in ones_length_test]

y_pred_avg
# Out:
# [11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499,
#  11.86897880539499]

# %%
# The mean absolute error
print("Mean absolute error: %.2f" % mean_absolute_error(y_test, y_pred_avg))
# Out:
# Mean absolute error: 2.29

# %%
## Rethink: Let's test which variables are correlated with G3 to use in linear regression

df_dropped = df_full.drop(['G1','G2'], axis=1)

# %%
df_dropped.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... romantic famrel  freetime  goout  Dalc Walc health absences  G3  \
# 0  ...       no      4         3      4     1    1      3        4  11
# 1  ...       no      5         3      3     1    1      3        2  11
# 2  ...       no      4         3      2     2    3      3        6  12
# 3  ...      yes      3         2      2     1    1      5        0  14
# 4  ...       no      4         3      2     1    2      5        0  13
# 5  ...       no      5         4      2     1    2      5        6  13
# 6  ...       no      4         4      4     1    1      3        0  13
# 7  ...       no      4         1      4     1    1      1        2  13
# 8  ...       no      4         2      2     1    1      1        0  17
# 9  ...       no      5         5      1     1    1      5        0  13
#
#   absences_bin
# 0            2
# 1            2
# 2            3
# 3            1
# 4            1
# 5            3
# 6            1
# 7            2
# 8            1
# 9            1
#
# [10 rows x 32 columns]

# %%
corr_matrix = df_dropped.corr()

corr_matrix['G3']
# Out:
# C:\Users\jboak\AppData\Local\Temp\ipykernel_17572\2939689472.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_dropped.corr()
# age            -0.106505
# Medu            0.240151
# Fedu            0.211800
# traveltime     -0.127173
# studytime       0.249789
# failures       -0.393316
# famrel          0.063361
# freetime       -0.122705
# goout          -0.087641
# Dalc           -0.204719
# Walc           -0.176619
# health         -0.098851
# absences       -0.091379
# G3              1.000000
# absences_bin   -0.060863
# Name: G3, dtype: float64

# %%
# I chose failures and Medu because: 
# 1) highly correlated with G3 and 
# 2) Had a nontrivial range, failures from 0 to 3 and Medu from 0 to 4

# Notice that absences has a higher correlation with G3 than absences_bin. 
# This seems to imply that absences_bin will be a worse predictor over absences, however
#     absences_bin does not have rare categories. 
#     This means that the training set will have enough representatives in each category.
#     I suspect that trees are sensitive to rare categories, but regression might be more robust to it.

# %%
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
# Ordinal variables may be treated as continuous and used in linear regression:
# https://www3.nd.edu/~rwilliam/stats3/OrdinalIndependent.pdf

# %%
# Feature engineering: rare categories.

df_full.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 absences_bin
# 0        3     4     1     1       3        4   0  11  11            2
# 1        3     3     1     1       3        2   9  11  11            2
# 2        3     2     2     3       3        6  12  13  12            3
# 3        2     2     1     1       5        0  14  14  14            1
# 4        3     2     1     2       5        0  11  13  13            1
#
# [5 rows x 34 columns]

# %%
df_full.shape
# Out:
# (649, 34)

# %%
df_full.shape[0]
# Out:
# 649

# %%
df_full['age'].value_counts()
# Out:
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: age, dtype: int64

# %%
df_full['age'].value_counts()/649*100
# Out:
# 17    27.580894
# 16    27.272727
# 18    21.571649
# 15    17.257319
# 19     4.930663
# 20     0.924499
# 21     0.308166
# 22     0.154083
# Name: age, dtype: float64

# %%
# Since age=19,20,21,22 are rare categories, we will group them into a single age '19'
# Define the function for binning:

def get_age(N):
    
    if N<19 :
        return N
            
    else:
        return 19

# %%
# Create a new feature 'age_bin' 


df_full['age_bin'] = df_full['age'].apply(get_age)

# %%
df_full[ df_full['age']>18 ].head(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 166     GP   M   19       U     GT3       T     3     2  services   at_home
# 224     GP   F   19       U     GT3       T     3     3     other     other
# 279     GP   M   22       U     GT3       T     3     1  services  services
# 290     GP   F   19       U     GT3       T     2     2  services  services
# 295     GP   M   19       U     LE3       A     4     3  services   at_home
# 299     GP   F   20       R     GT3       T     2     1     other     other
# 311     GP   F   19       U     GT3       T     3     3     other  services
# 322     GP   F   19       R     GT3       T     3     2  services  services
# 341     GP   F   19       U     GT3       T     4     4    health     other
#
#      ... goout Dalc  Walc  health  absences  G1  G2  G3 absences_bin age_bin
# 127  ...     2    1     1       5         0   9  10  11            1      19
# 166  ...     4    1     1       4         6  11   9  11            3      19
# 224  ...     3    1     2       3         4  12  12  12            2      19
# 279  ...     5    5     5       1        12   7   8   5            3      19
# 290  ...     3    1     1       5         0  10  10  11            1      19
# 295  ...     1    1     1       1         4  11  13  14            2      19
# 299  ...     3    1     2       2         8  10  12  12            3      19
# 311  ...     5    3     3       5        16  11  12  12            3      19
# 322  ...     3    4     3       3         0   9   8  10            1      19
# 341  ...     4    2     3       2         2  14  13  13            2      19
#
# [10 rows x 35 columns]

# %%
sns.catplot(data=df_full, x="age", y="G3"
            #, kind="swarm", s = 2
           , kind="box"
           )

# %%
sns.catplot(data=df_full, x="age_bin", y="G3"
            #, kind="swarm", s = 2
           , kind="box"
           )

# %%
for col in df_full.columns:
    print(col)
    print(df_full[col].value_counts()/649*100)
    print(' ')    
    print(' ')
# Out:
# school
# GP    65.177196
# MS    34.822804
# Name: school, dtype: float64
#
#
# sex
# F    59.013867
# M    40.986133
# Name: sex, dtype: float64
#
#
# age
# 17    27.580894
# 16    27.272727
# 18    21.571649
# 15    17.257319
# 19     4.930663
# 20     0.924499
# 21     0.308166
# 22     0.154083
# Name: age, dtype: float64
#
#
# address
# U    69.645609
# R    30.354391
# Name: address, dtype: float64
#
#
# famsize
# GT3    70.416025
# LE3    29.583975
# Name: famsize, dtype: float64
#
#
# Pstatus
# T    87.673344
# A    12.326656
# Name: Pstatus, dtype: float64
#
#
# Medu
# 2    28.659476
# 4    26.964561
# 1    22.033898
# 3    21.417565
# 0     0.924499
# Name: Medu, dtype: float64
#
#
# Fedu
# 2    32.203390
# 1    26.810478
# 3    20.184900
# 4    19.722650
# 0     1.078582
# Name: Fedu, dtype: float64
#
#
# Mjob
# other       39.753467
# services    20.955316
# at_home     20.801233
# teacher     11.093991
# health       7.395994
# Name: Mjob, dtype: float64
#
#
# Fjob
# other       56.548536
# services    27.889060
# at_home      6.471495
# teacher      5.546995
# health       3.543914
# Name: Fjob, dtype: float64
#
#
# reason
# course        43.913713
# home          22.958398
# reputation    22.033898
# other         11.093991
# Name: reason, dtype: float64
#
#
# guardian
# mother    70.107858
# father    23.574730
# other      6.317411
# Name: guardian, dtype: float64
#
#
# traveltime
# 1    56.394453
# 2    32.819723
# 3     8.320493
# 4     2.465331
# Name: traveltime, dtype: float64
#
#
# studytime
# 2    46.995378
# 1    32.665639
# 3    14.946071
# 4     5.392912
# Name: studytime, dtype: float64
#
#
# failures
# 0    84.591680
# 1    10.785824
# 2     2.465331
# 3     2.157165
# Name: failures, dtype: float64
#
#
# schoolsup
# no     89.522342
# yes    10.477658
# Name: schoolsup, dtype: float64
#
#
# famsup
# yes    61.325116
# no     38.674884
# Name: famsup, dtype: float64
#
#
# paid
# no     93.990755
# yes     6.009245
# Name: paid, dtype: float64
#
#
# activities
# no     51.46379
# yes    48.53621
# Name: activities, dtype: float64
#
#
# nursery
# yes    80.27735
# no     19.72265
# Name: nursery, dtype: float64
#
#
# higher
# yes    89.368259
# no     10.631741
# Name: higher, dtype: float64
#
#
# internet
# yes    76.733436
# no     23.266564
# Name: internet, dtype: float64
#
#
# romantic
# no     63.174114
# yes    36.825886
# Name: romantic, dtype: float64
#
#
# famrel
# 4    48.844376
# 5    27.734977
# 3    15.562404
# 2     4.468413
# 1     3.389831
# Name: famrel, dtype: float64
#
#
# freetime
# 3    38.674884
# 4    27.426810
# 2    16.486903
# 5    10.477658
# 1     6.933744
# Name: freetime, dtype: float64
#
#
# goout
# 3    31.587057
# 2    22.342065
# 4    21.725732
# 5    16.949153
# 1     7.395994
# Name: goout, dtype: float64
#
#
# Dalc
# 1    69.491525
# 2    18.644068
# 3     6.625578
# 5     2.619414
# 4     2.619414
# Name: Dalc, dtype: float64
#
#
# Walc
# 1    38.058552
# 2    23.112481
# 3    18.489985
# 4    13.405239
# 5     6.933744
# Name: Walc, dtype: float64
#
#
# health
# 5    38.366718
# 3    19.106317
# 4    16.640986
# 1    13.867488
# 2    12.018490
# Name: health, dtype: float64
#
#
# absences
# 0     37.596302
# 2     16.949153
# 4     14.329738
# 6      7.550077
# 8      6.471495
# 10     3.235747
# 1      1.848998
# 12     1.848998
# 5      1.848998
# 16     1.540832
# 14     1.232666
# 9      1.078582
# 3      1.078582
# 11     0.770416
# 18     0.462250
# 7      0.462250
# 21     0.308166
# 15     0.308166
# 22     0.308166
# 30     0.154083
# 26     0.154083
# 24     0.154083
# 13     0.154083
# 32     0.154083
# Name: absences, dtype: float64
#
#
# G1
# 10    14.637904
# 11    14.021572
# 12    12.634823
# 13    11.093991
# 14    10.939908
# 9     10.015408
# 8      6.471495
# 15     5.392912
# 7      5.084746
# 16     3.389831
# 17     2.465331
# 6      1.386749
# 18     1.078582
# 5      0.770416
# 4      0.308166
# 0      0.154083
# 19     0.154083
# Name: G1, dtype: float64
#
#
# G2
# 11    15.870570
# 12    13.251156
# 10    12.788906
# 13    12.326656
# 9     11.093991
# 14     8.320493
# 8      6.163328
# 15     5.855162
# 16     3.852080
# 17     3.081664
# 7      2.465331
# 18     2.157165
# 6      1.078582
# 0      1.078582
# 5      0.462250
# 19     0.154083
# Name: G2, dtype: float64
#
#
# G3
# 11    16.024653
# 10    14.946071
# 13    12.634823
# 12    11.093991
# 14     9.707242
# 15     7.550077
# 16     5.546995
# 9      5.392912
# 8      5.392912
# 17     4.468413
# 18     2.311248
# 0      2.311248
# 7      1.540832
# 6      0.462250
# 19     0.308166
# 1      0.154083
# 5      0.154083
# Name: G3, dtype: float64
#
#
# absences_bin
# 1    37.596302
# 2    34.206471
# 3    28.197227
# Name: absences_bin, dtype: float64
#
#
# age_bin
# 17    27.580894
# 16    27.272727
# 18    21.571649
# 15    17.257319
# 19     6.317411
# Name: age_bin, dtype: float64

# %%
# Since Medu=0 is a rare category, we will group it with the category '1'
# Similarly for Fedu=0
# Define the function for binning:

def get_edu(N):
    
    if N<1 :
        return 1
            
    else:
        return N

# %%
# Create new features 'Medu_bin' and 'Fedu_bin' 


df_full['Medu_bin'] = df_full['Medu'].apply(get_edu)
df_full['Fedu_bin'] = df_full['Fedu'].apply(get_edu)

# %%
df_full.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... Walc health  absences  G1  G2  G3 absences_bin age_bin Medu_bin  \
# 0  ...    1      3         4   0  11  11            2      18        4
# 1  ...    1      3         2   9  11  11            2      17        1
# 2  ...    3      3         6  12  13  12            3      15        1
# 3  ...    1      5         0  14  14  14            1      15        4
# 4  ...    2      5         0  11  13  13            1      16        3
# 5  ...    2      5         6  12  12  13            3      16        4
# 6  ...    1      3         0  13  12  13            1      16        2
# 7  ...    1      1         2  10  13  13            2      17        4
# 8  ...    1      1         0  15  16  17            1      15        3
# 9  ...    1      5         0  12  12  13            1      15        3
#
#   Fedu_bin
# 0        4
# 1        1
# 2        1
# 3        2
# 4        3
# 5        3
# 6        2
# 7        4
# 8        2
# 9        4
#
# [10 rows x 37 columns]

# %%
df_full[ df_full['Medu']<1 ].head(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 127     GP   F   19       U     GT3       T     0     1  at_home    other
# 281     GP   M   16       U     GT3       T     0     2    other    other
# 375     GP   F   17       U     LE3       T     0     2  at_home  at_home
# 437     MS   F   16       R     GT3       T     0     2    other    other
# 493     MS   F   17       U     GT3       T     0     1    other  at_home
# 584     MS   F   17       R     GT3       T     0     0  at_home    other
#
#      ... Walc health  absences  G1  G2  G3 absences_bin age_bin Medu_bin  \
# 127  ...    1      5         0   9  10  11            1      19        1
# 281  ...    4      5         0  11  12  11            1      16        1
# 375  ...    3      2         0  14  14  15            1      17        1
# 437  ...    2      2         0  12  11  12            1      16        1
# 493  ...    5      5         5   9   9  10            3      17        1
# 584  ...    1      5         0  10  11  11            1      17        1
#
#     Fedu_bin
# 127        1
# 281        2
# 375        2
# 437        2
# 493        1
# 584        1
#
# [6 rows x 37 columns]

# %%
# Fjob = health is a rare category at 3.5% representation.
# From the following box plot, we see 'health' has a similar distribution as 'other', 
#    so we will group those categories together into the bin called 'other'

sns.catplot(data=df, x="Fjob", y="G3", kind="box" )

# %%
def get_Fjob(N):
    
    if N=='health' :
        return 'other'
            
    else:
        return N

# %%
# Create a new feature 'Fjob_bin' 

df_full['Fjob_bin'] = df_full['Fjob'].apply(get_Fjob)

# %%
df_full.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... health absences  G1  G2  G3 absences_bin age_bin Medu_bin Fedu_bin  \
# 0  ...      3        4   0  11  11            2      18        4        4
# 1  ...      3        2   9  11  11            2      17        1        1
# 2  ...      3        6  12  13  12            3      15        1        1
# 3  ...      5        0  14  14  14            1      15        4        2
# 4  ...      5        0  11  13  13            1      16        3        3
# 5  ...      5        6  12  12  13            3      16        4        3
# 6  ...      3        0  13  12  13            1      16        2        2
# 7  ...      1        2  10  13  13            2      17        4        4
# 8  ...      1        0  15  16  17            1      15        3        2
# 9  ...      5        0  12  12  13            1      15        3        4
#
#    Fjob_bin
# 0   teacher
# 1     other
# 2     other
# 3  services
# 4     other
# 5     other
# 6     other
# 7   teacher
# 8     other
# 9     other
#
# [10 rows x 38 columns]

# %%
# traveltime = 4 is a rare category at 2.5% representation. Combine traveltime = 3 and 4 to the category '3'.

def get_traveltime(N):
    
    if N>3 :
        return 3
            
    else:
        return N

# %%
# Create a new feature 'Fjob_bin' 

df_full['traveltime_bin'] = df_full['traveltime'].apply(get_traveltime)

# %%
df_full.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... absences  G1  G2  G3  absences_bin age_bin Medu_bin Fedu_bin  Fjob_bin  \
# 0  ...        4   0  11  11             2      18        4        4   teacher
# 1  ...        2   9  11  11             2      17        1        1     other
# 2  ...        6  12  13  12             3      15        1        1     other
# 3  ...        0  14  14  14             1      15        4        2  services
# 4  ...        0  11  13  13             1      16        3        3     other
# 5  ...        6  12  12  13             3      16        4        3     other
# 6  ...        0  13  12  13             1      16        2        2     other
# 7  ...        2  10  13  13             2      17        4        4   teacher
# 8  ...        0  15  16  17             1      15        3        2     other
# 9  ...        0  12  12  13             1      15        3        4     other
#
#   traveltime_bin
# 0              2
# 1              1
# 2              1
# 3              1
# 4              1
# 5              1
# 6              1
# 7              2
# 8              1
# 9              1
#
# [10 rows x 39 columns]

# %%
# failures = 2,3 are a rare categories at 2.5% and 2.2% representation, respectively. 
#Combine failures = 1,2,3 to the category '1'.

def get_failures(N):
    
    if N>0 :
        return 1
            
    else:
        return N

# %%
# Create a new feature 'failures_bin' 

df_full['failures_bin'] = df_full['failures'].apply(get_failures)

# %%
df_full.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#    G1  G2  G3  absences_bin  age_bin Medu_bin Fedu_bin  Fjob_bin  \
# 0   0  11  11             2       18        4        4   teacher
# 1   9  11  11             2       17        1        1     other
# 2  12  13  12             3       15        1        1     other
# 3  14  14  14             1       15        4        2  services
# 4  11  13  13             1       16        3        3     other
#
#   traveltime_bin failures_bin
# 0              2            0
# 1              1            0
# 2              1            0
# 3              1            0
# 4              1            0
#
# [5 rows x 40 columns]

# %%
df_full[ df_full['failures']>0 ].head(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 44      GP   F   16       U     LE3       T     2     2     other   at_home
# 78      GP   M   17       U     GT3       T     2     1     other     other
# 112     GP   F   16       U     GT3       T     2     2   at_home     other
# 118     GP   M   17       R     GT3       T     1     3     other     other
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 131     GP   F   18       U     GT3       T     2     1  services     other
# 137     GP   F   16       U     GT3       A     2     2     other     other
# 146     GP   M   16       U     LE3       T     1     1  services     other
# 148     GP   F   15       R     GT3       T     1     1     other     other
#
#      ...  G1  G2  G3  absences_bin  age_bin Medu_bin Fedu_bin  Fjob_bin  \
# 18   ...   8   8   7             2       17        3        2  services
# 44   ...  10  11  11             3       16        2        2   at_home
# 78   ...   9   9  10             1       17        2        1     other
# 112  ...   8  10  10             3       16        2        2     other
# 118  ...  12  11  11             3       17        1        3     other
# 127  ...   9  10  11             1       19        1        1     other
# 131  ...  10   9   8             3       18        2        1     other
# 137  ...  13  11  11             3       16        2        2     other
# 146  ...  10  10  10             1       16        1        1     other
# 148  ...   8   9   9             2       15        1        1     other
#
#     traveltime_bin failures_bin
# 18               1            1
# 44               2            1
# 78               2            1
# 112              1            1
# 118              3            1
# 127              1            1
# 131              1            1
# 137              1            1
# 146              1            1
# 148              3            1
#
# [10 rows x 40 columns]

# %%
sns.catplot(data=df_full, x="failures_bin", y="G3", kind="box" )

# %%
# famrel = 1,2 are a rare categories at 4.5% and 3.5% representation, respectively. 
#Combine famrel = 1,2 into the category '2'.

def get_famrel(N):
    
    if N<3 :
        return 2
            
    else:
        return N

# %%
# Create a new feature 'famrel_bin' 

df_full['famrel_bin'] = df_full['famrel'].apply(get_famrel)

# %%
df_full.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#    G2  G3  absences_bin  age_bin  Medu_bin Fedu_bin  Fjob_bin traveltime_bin  \
# 0  11  11             2       18         4        4   teacher              2
# 1  11  11             2       17         1        1     other              1
# 2  13  12             3       15         1        1     other              1
# 3  14  14             1       15         4        2  services              1
# 4  13  13             1       16         3        3     other              1
#
#   failures_bin famrel_bin
# 0            0          4
# 1            0          5
# 2            0          4
# 3            0          3
# 4            0          4
#
# [5 rows x 41 columns]

# %%
sns.catplot(data=df_full, x="famrel_bin", y="G3", kind="box" )

# %%
# Dalc = 4,5 are a rare categories at 2.6% representation each. 
# Combine Dalc = 4,5 into the category '4'.

def get_Dalc(N):
    
    if N>3 :
        return 4
            
    else:
        return N

# %%
# Create a new feature 'Dalc_bin' 

df_full['Dalc_bin'] = df_full['Dalc'].apply(get_Dalc)

# %%
df_full.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#    G3 absences_bin  age_bin  Medu_bin  Fedu_bin  Fjob_bin traveltime_bin  \
# 0  11            2       18         4         4   teacher              2
# 1  11            2       17         1         1     other              1
# 2  12            3       15         1         1     other              1
# 3  14            1       15         4         2  services              1
# 4  13            1       16         3         3     other              1
#
#   failures_bin famrel_bin Dalc_bin
# 0            0          4        1
# 1            0          5        1
# 2            0          4        2
# 3            0          3        1
# 4            0          4        1
#
# [5 rows x 42 columns]

# %%
sns.catplot(data=df_full, x="Dalc_bin", y="G3", kind="box" )

# %%
# Add polynomial features.

# 'freetime' and 'goout' should have a quadratic fit and not a linear fit. 
#     The reason behind this decision is that some relaxation (i.e. free time or going out) correlates to an improvment in 'G3',
#     whereas too much relaxation correlates to a decrease in 'G3'. 
#     We demonstrate this by showing the box plot for 'freetime' and 'goout'

sns.catplot(data=df, x="freetime", y="G3", kind="box")

# %%
sns.catplot(data=df, x="goout", y="G3", kind="box")

# %%
# We now add those polynomial features 'freetime'^2 and 'goout'^2

df_full['freetime_squared'] = df_full['freetime']**2
df_full['goout_squared'] = df_full['goout']**2

# %%
df_full.iloc[ :10, 24: ]
# Out:
#    freetime  goout  Dalc  Walc  health  absences  G1  G2  G3  absences_bin  \
# 0         3      4     1     1       3         4   0  11  11             2
# 1         3      3     1     1       3         2   9  11  11             2
# 2         3      2     2     3       3         6  12  13  12             3
# 3         2      2     1     1       5         0  14  14  14             1
# 4         3      2     1     2       5         0  11  13  13             1
# 5         4      2     1     2       5         6  12  12  13             3
# 6         4      4     1     1       3         0  13  12  13             1
# 7         1      4     1     1       1         2  10  13  13             2
# 8         2      2     1     1       1         0  15  16  17             1
# 9         5      1     1     1       5         0  12  12  13             1
#
#    age_bin  Medu_bin  Fedu_bin  Fjob_bin  traveltime_bin  failures_bin  \
# 0       18         4         4   teacher               2             0
# 1       17         1         1     other               1             0
# 2       15         1         1     other               1             0
# 3       15         4         2  services               1             0
# 4       16         3         3     other               1             0
# 5       16         4         3     other               1             0
# 6       16         2         2     other               1             0
# 7       17         4         4   teacher               2             0
# 8       15         3         2     other               1             0
# 9       15         3         4     other               1             0
#
#    famrel_bin  Dalc_bin  freetime_squared  goout_squared
# 0           4         1                 9             16
# 1           5         1                 9              9
# 2           4         2                 9              4
# 3           3         1                 4              4
# 4           4         1                 9              4
# 5           5         1                16              4
# 6           4         1                16             16
# 7           4         1                 1             16
# 8           4         1                 4              4
# 9           5         1                25              1
